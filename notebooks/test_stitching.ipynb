# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import numpy as np 
from tqdm import tqdm
import stackview
from functools import partial

from codex.data.codex_dataset import CodexDataset
from codex.preprocessing.stitching import Ashlar, M2Stitch
from codex.utils.io import save_raw_tile_stack,save_raw_img
from codex.preprocessing.nodes import StitchingNode

# %%
out_dir = "../../outputs/"

# %%
node = StitchingNode(
    algorithm=partial(Ashlar, align_channel=1, max_shift=100, filter_sigma=0, ome=False),
    # algorithm=partial(M2Stitch, align_cycle=1, align_channel=1, max_cores=4, use_gpu=True),
    ds=CodexDataset(
        root_dir=Path("../../outputs/illumination_correction"),
        mode="raw",
        lazy_loading=False,
        read_markers=False,
    ),
    out_dir=out_dir,
    n_jobs=4,
    out_fmt="raw",
)

# %%
node.run()
