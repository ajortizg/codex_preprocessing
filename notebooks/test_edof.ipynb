# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

import os
from pathlib import Path

import stackview
import numpy as np

from codex.data.codex_dataset import CodexDataset
from codex.preprocessing.edof import *
from codex.preprocessing.nodes import EDoFNode

os.environ["CUDA_VISIBLE_DEVICES"] = "0,1,2,3,4,5,6,7"
# Out:
# 2025-08-10 14:54:39.080918: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754830479.096840 2920425 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754830479.101852 2920425 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-08-10 14:54:39.123147: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
out_dir = "../../outputs"
devices = [0, 1, 2, 3]

ds = CodexDataset(
    root_dir=Path("../../outputs/deconvolution/"),
    mode="raw",
    lazy_loading=False,
    read_markers=False,
)

node = EDoFNode(EDoFWavelet(), ds, out_dir, devices)
node.run()
# Out:
# 2025-08-10 14:54:47.430012: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754830487.443846 2920688 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754830487.448342 2920688 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-08-10 14:54:47.483116: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
ds_edof = CodexDataset(
    root_dir=Path("../../outputs/edof/"),
    mode="raw",
    lazy_loading=False,
    read_markers=False,
)
ds_edof.group_channels()
ds_edof.df
# Out:
#      cycle  region  tile  zslice       channel  \
# 0        1       1     1       1  [1, 2, 3, 4]
# 1        1       1     2       1  [1, 2, 3, 4]
# 2        1       1     3       1  [1, 2, 3, 4]
# 3        1       1     4       1  [1, 2, 3, 4]
# 4        1       1     5       1  [1, 2, 3, 4]
# ..     ...     ...   ...     ...           ...
# 247      6       1    38       1  [1, 2, 3, 4]
# 248      6       1    39       1  [1, 2, 3, 4]
# 249      6       1    40       1  [1, 2, 3, 4]
# 250      6       1    41       1  [1, 2, 3, 4]
# 251      6       1    42       1  [1, 2, 3, 4]
#
#                                               img_path
# 0    [../../outputs/edof/cyc001_reg001/1_00001_Z001...
# 1    [../../outputs/edof/cyc001_reg001/1_00002_Z001...
# 2    [../../outputs/edof/cyc001_reg001/1_00003_Z001...
# 3    [../../outputs/edof/cyc001_reg001/1_00004_Z001...
# 4    [../../outputs/edof/cyc001_reg001/1_00005_Z001...
# ..                                                 ...
# ...

# %%
stackview.histogram(ds_edof[100]["img"], zoom_factor=0.2, continuous_update=True)
